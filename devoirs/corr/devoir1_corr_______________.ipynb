# %% [markdown]
# <div style='background-color: #dda0dd;
#     border: 0.5em solid black;
#     border-radius: 0.5em;
#     padding: 1em;'>
#     <h2>Devoir surveillé</h2>
#     <h1>Corrigé du devoir n°1</h1>
# </div>

# %% [markdown]
# <div style='background-color: #dda0dd;
#     border-radius: 0.5em;
#     padding: 1em;'>
#     <h2>Première partie</h2>
# </div>

# %% [markdown]
# ## Exercice 1
#
# On considère le code suivant :
#
# ```python
# nombre = 0
# produit = 1
# while produit < 100:
#     nombre = nombre + 1
#     if nombre >= 3:
#         produit = produit * nombre * nombre
#     else:
#         produit = produit * nombre
# print(nombre)
# print(produit)
# ```
#
# **(1)** Dresser la liste des variables utilisées.
#
# Les deux variables utilisées sont `nombre` et `produit`.
#
# **(2)** Repérer l’ensemble des affectations, en indiquant à chaque fois le numéro de ligne.
#
# Les affectations sont `nombre = 0` (ligne 1), `produit = 1` (ligne 2), `nombre = nombre + 1` (ligne 4), `produit = produit * nombre * nombre` (ligne 6) et `produit = produit * nombre` (ligne 8).
#
# **(3)** Repérer les instructions conditionnelles, en indiquant à chaque fois le numéro de ligne de début et de fin.
#
# La seule instruction conditionnelle débute à la ligne 5 et termine à la ligne 8.
#
# **(4)** Repérer les boucles, en indiquant à chaque fois le numéro de ligne de début et de fin.
#
# La seule boucle (non bornée, ou boucle Tant que) débute à la ligne 3 et termine à la ligne 8.
#
# **(5)** Compléter les cases blanches du tableau représentant l’état de la mémoire après l’exécution de chaque ligne de l’algorithme.
#
# _n.e._ signifie que la ligne n'est pas exécutée.
#
# Ligne de code                                | `nombre` | `produit` | _Test_
# :--------------------------------------------|:--------:|:---------:|:-------:
# `nombre = 0`                                 | 0        |           |
# `produit = 1`                                | 0        | 1         |
# `while produit < 100:`                       |          |           | Vrai
# `    nombre = nombre + 1`                    | 1        | 1         |
# `    if nombre >= 3:`                        |          |           | Faux
# `        produit = produit * nombre * nombre`| _n.e._   | _n.e._    |
# `    else:`                                  |          |           |
# `        produit = produit * nombre`         | 1        | 1         |
# `while produit < 100:`                       |          |           | Vrai
# `    nombre = nombre + 1`                    | 2        | 1         |
# `    if nombre >= 3:`                        |          |           | Faux
# `        produit = produit * nombre * nombre`| _n.e._   | _n.e._    |
# `    else:`                                  |          |           |
# `        produit = produit * nombre`         | 2        | 2         |
# `while produit < 100:`                       |          |           | Vrai
# `    nombre = nombre + 1`                    | 3        | 2         |
# `    if nombre >= 3:`                        |          |           | Vrai
# `        produit = produit * nombre * nombre`| 3        | 18        |
# `    else:`                                  |          |           |
# `        produit = produit * nombre`         | _n.e._   | _n.e._    |
# `while produit < 100:`                       |          |           | Vrai
# `    nombre = nombre + 1`                    | 4        | 18        |
# `    if nombre >= 3:`                        |          |           | Vrai
# `        produit = produit * nombre * nombre`| 4        | 288       |
# `    else:`                                  |          |           |
# `        produit = produit * nombre`         | _n.e._   | _n.e._    |
# `while produit < 100:`                       |          |           | Faux
# `    nombre = nombre + 1`                    | _n.e._   | _n.e._    |
# `    if nombre >= 3:`                        |          |           | _n.e._
# `        produit = produit * nombre * nombre`| _n.e._   | _n.e._    |
# `    else:`                                  |          |           |
# `        produit = produit * nombre`         | _n.e._   | _n.e._    |
# `print(nombre)`                              | 4        | 288       |
# `print(produit)`                             | 4        | 288       |
#
# **(6)** Quelles valeurs sont affichées à l’écran à la fin de l’exécution ?
#
# À la fin de l'exécution, les valeurs `4` et `288` sont affichées à l'écran.
#
# ## Exercice 2
#
# Voici les règles d’un petit jeu :
#
# - L’ordinateur lance 9 fois de suite deux dés équilibrés, et il compte le nombre de fois où la somme des deux dés vaut 7.
# - Si au moins deux sommes sont égales à 7, le joueur a gagné. Dans le cas contraire, le joueur a perdu.
#
# **(1)** Parmi les instructions Python suivantes, laquelle permet de simuler le lancer d’un dé équilibré ? Justifier.
#
# - Réponse A : `randint(1, 2, 3, 4, 5, 6)`
# - Réponse B : `randint(0, 1)`
# - Réponse C : `randint(1, 6)`
# - Réponse D : `randint(de)`
#
# La bonne réponse est la réponse C. Simuler le lancer d'un dé équilibré, c'est choisir aléatoirement un entier de l'intervalle $[1;6]$, les six issues étant équiprobables. C'est l'expression `randint(1, 6)` qui permet de faire cela.
#
# **(2)** À partir des lignes de code ci-dessous, reconstituer l’algorithme qui simule une partie de ce jeu, en prenant soin d’indenter correctement le code.
#
# ```python
# de_1 = randint(......)                  cpt = 0
# cpt = 0                                 for k in range(9):
# cpt = cpt + 1                               de_1 = randint(1, 6)
# else:                                       de_2 = randint(1, 6)
# if de_1 + de_2 == 7:                        if de_1 + de_2 == 7:
# if cpt >= 2:                                    cpt = cpt + 1
# print("Bravo !")                        if cpt >= 2:
# for k in range(9):                          print("Bravo !")
# de_2 = randint(......)                  else:
# print("Perdu !")                            print("Perdu !")
# ```
#
# **(3)** Écrire un programme qui simule plusieurs parties de ce jeu et qui affiche à l’écran le nombre de défaites subies par le joueur avant sa première victoire.
#
# ```python
# from random import randint
#
# nb_defaites = -1
# cpt = 0
# while cpt < 2:
#     cpt = 0
#     nb_defaites = nb_defaites + 1
#     for k in range(9):
#         de_1 = randint(1, 6)
#         de_2 = randint(1, 6)
#         if de_1 + de_2 == 7:
#             cpt = cpt + 1
# print("Nombre de défaites avant la première victoire :", nb_defaites)
# ```

# %% [markdown]
# <div style='background-color: #dda0dd;
#     border-radius: 0.5em;
#     padding: 1em;'>
#     <h2>Seconde partie</h2>
# </div>

# %% [markdown]
# ## Exercice 3
#
# Le code ci-dessous contient six erreurs que vous devez corriger. Vous expliquerez vos modifications dans la cellule située sous le code.
#
# *Remarque :* La première réponse est donnée à titre d'exemple.

# %%
    from random import randint

nom_du_joueur = input('Veuillez saisir votre nom : ')  # Saisie d'une chaîne de caractère (texte)
print('*** Bienvenue', nom_du_joueur, '! ***')

annee_naissance = int(input('Veuillez saisir votre année de naissance : '))  # Saisie d'un nombre entier
print()

for annee in range(2034, 2023):
    age = annee - annee_naissance  # Calcul de l'âge
    print('En', annee, ', vous fêterez vos', age, 'ans.')
    if age = 18: # Âge de la majorité ?
        prit('--> Félicitations ! Vous serez majeur en', annee, '!')
print()

annee = randint(2050, 2060)
age = annee - annee_naissance
while age <= 80
    print('En', annee, ', vous fêterez vos', age 'ans.')
    annee = annee + 1
    age = age + 1

# %% [markdown]
# **0.** Erreur à la **ligne 1**
#
# Version initiale de la ligne de code : `    from random import randint`
#
# Version corrigée de la ligne de code : `from random import randint`
#
# _Explication :_ La première ligne de code ne doit pas être indentée.
#
# **1.** Erreur à la **ligne 9**
#
# Version initiale de la ligne de code : `for annee in range(2034, 2023):`
#
# Version corrigée de la ligne de code : `for annee in range(2023, 2034):`
#
# _Explication :_ Si `range` contient deux entiers dans l'ordre décroissant, on n'entre jamais dans la boucle.
#
# **2.** Erreur à la **ligne 12**
#
# Version initiale de la ligne de code : `if age = 18:`
#
# Version corrigée de la ligne de code : `if age == 18:`
#
# _Explication :_ `=` sert à faire une affectation. Pour tester l'égalité entre deux valeurs, on utilise le symbole `==`.
#
# **3.** Erreur à la **ligne 13**
#
# Version initiale de la ligne de code : `prit('--> Félicitations ! Vous serez majeur en', annee, '!')`
#
# Version corrigée de la ligne de code : `print('--> Félicitations ! Vous serez majeur en', annee, '!')`
#
# _Explication :_ La fonction d'affichage s'appelle `print` et pas `prit`.
#
# **4.** Erreur à la **ligne 18**
#
# Version initiale de la ligne de code : `while age <= 80`
#
# Version corrigée de la ligne de code : `while age <= 80:`
#
# _Explication :_ Une ligne qui commence par `while` (ou par `for`, ou par `if`) se termine par `:`.
#
# **5.** Erreur à la **ligne 19**
#
# Version initiale de la ligne de code : `print('En', annee, ', vous fêterez vos', age 'ans.')`
#
# Version corrigée de la ligne de code : `print('En', annee, ', vous fêterez vos', age, 'ans.')`
#
# _Explication :_ L'oubli d'une virgule provoque une erreur de syntaxe.

# %% [markdown]
# ## Exercice 4
#
# On souhaite simuler une partie du jeu du _Juste prix_ :
#
# - L'ordinateur tire un nombre entier au hasard compris entre 500 et 2000 : c'est le prix à deviner.
# - Le joueur ou la joueuse propose des prix jusqu'à trouver la valeur choisie par l'ordinateur.
# - Après chaque proposition fausse du joueur ou de la joueuse, l'ordinateur annonce si la bonne réponse est supérieure ou inférieure à la proposition faite.
# - À la fin du jeu, une fois que le juste prix a été deviné, l'ordinateur affiche à l'écran le nombre de tentatives qui ont été réalisées.
#
# _Remarque :_ On rappelle que, pour demander au joueur ou à la joueuse de saisir un entier au clavier, on utilise l'instruction suivante :
#
# ```python
# proposition = int(input("Saisir une proposition : "))
# ```

# %%
from random import randint

juste_prix = randint(500, 2000)
proposition = 0
cpt = 0
while proposition != juste_prix:
    proposition = int(input("Saisir une proposition : "))
    cpt = cpt + 1
    if proposition > juste_prix:
        print("Le prix à deviner est plus petit !")
    elif proposition < juste_prix:
        print("Le prix à deviner est plus grand !")
print("Vous avez trouvé le juste prix au bout de", cpt, "tentatives.")
